# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Abdul-Rafe-Sajid/Deep-Learning-/blob/main/LAB_6-VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================================
# Experiment: Implementation of VGG16 on CIFAR-10 using TensorFlow
# Author: Your Name
# Dataset: CIFAR-10
# Framework: TensorFlow / Keras
# ================================================================

# ---------------------------
# 1. Import Required Libraries
# ---------------------------
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# ---------------------------
# 2. Load CIFAR-10 Dataset
# ---------------------------
# CIFAR-10 contains 60,000 color images (32x32) across 10 classes
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# ---------------------------
# 3. Data Preprocessing
# ---------------------------

# Normalize pixel values from [0,255] to [0,1]
x_train = x_train / 255.0
x_test = x_test / 255.0

# Convert labels to one-hot encoded vectors
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# ---------------------------
# 4. Build VGG16 Architecture
# ---------------------------

model = models.Sequential()

# ----- Convolution Block 1 -----
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same',
                        input_shape=(32,32,3)))
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# ----- Convolution Block 2 -----
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# ----- Convolution Block 3 -----
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# ----- Convolution Block 4 -----
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# ----- Convolution Block 5 -----
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2,2)))

# ---------------------------
# 5. Fully Connected Layers
# ---------------------------
model.add(layers.Flatten())

model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))

# Output layer for 10 classes
model.add(layers.Dense(10, activation='softmax'))

# ---------------------------
# 6. Compile Model
# ---------------------------
model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ---------------------------
# 7. Early Stopping Callback
# ---------------------------
# Stops training if validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3
)

# ---------------------------
# 8. Train Model
# ---------------------------
history = model.fit(
    x_train,
    y_train,
    epochs=30,
    batch_size=64,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping]
)

# ---------------------------
# 9. Evaluate Model
# ---------------------------
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 72ms/step - accuracy: 0.0991 - loss: 2.3033 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.1009 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.0969 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.0966 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.0971 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 8/30
# ...

# %% [markdown]
# # VGG16 Implementation on CIFAR-10 using TensorFlow/Keras
#
# ## Overview
# This project implements the **VGG16 Convolutional Neural Network architecture** for image classification on the **CIFAR-10 dataset** using **TensorFlow and Keras**.
#
# The goal is to train a deep CNN model capable of learning hierarchical image features and classify images into 10 categories.
#
# ---
#
# ## Dataset: CIFAR-10
#
# CIFAR-10 is a standard benchmark dataset used in computer vision research.
#
# ### Dataset Details
#
# | Property | Value |
# |--------|--------|
# | Total Images | 60,000 |
# | Training Images | 50,000 |
# | Testing Images | 10,000 |
# | Image Size | 32 × 32 |
# | Channels | RGB (3) |
# | Number of Classes | 10 |
#
# ### Classes
#
# - Airplane
# - Automobile
# - Bird
# - Cat
# - Deer
# - Dog
# - Frog
# - Horse
# - Ship
# - Truck
#
# ---
#
# ### Architecture Structure
#
# ```
# Input Image (32x32x3)
#         │
#         ▼
# Conv Block 1 (64 filters)
#         │
#         ▼
# Conv Block 2 (128 filters)
#         │
#         ▼
# Conv Block 3 (256 filters)
#         │
#         ▼
# Conv Block 4 (512 filters)
#         │
#         ▼
# Conv Block 5 (512 filters)
#         │
#         ▼
# Flatten
#         │
#         ▼
# Dense (4096)
#         │
#         ▼
# Dropout
#         │
#         ▼
# Dense (4096)
#         │
#         ▼
# Dropout
#         │
#         ▼
# Dense (10) → Softmax Output
# ```
#
#
# ### Key Features
#
# - Uses **small 3×3 convolution filters**
# - Deep architecture improves **feature extraction**
# - **ReLU activation** for non-linearity
# - **Dropout layers** to reduce overfitting
# - **Softmax output layer** for classification
#
# ---
#
# ## Training Configuration
#
# | Parameter | Value |
# |--------|--------|
# | Optimizer | Adam |
# | Loss Function | Categorical Crossentropy |
# | Epochs | 50 |
# | Batch Size | 64 |
# | Callback | EarlyStopping |
# | Framework | TensorFlow / Keras |
#
# EarlyStopping stops training if validation loss does not improve for **3 epochs**.
#
# ---
#
# ## Implementation Steps
#
# 1. Import TensorFlow and Keras libraries
# 2. Load the CIFAR-10 dataset
# 3. Normalize image pixel values
# 4. Convert labels to one-hot encoding
# 5. Build the VGG16 model architecture
# 6. Compile the model using Adam optimizer
# 7. Train the model with early stopping
# 8. Evaluate performance on test data
#
# ---
#
# ## VGG16 vs AlexNet Comparison
#
# | Feature | VGG16 | AlexNet |
# |------|------|------|
# | Year | 2014 | 2012 |
# | Layers | 16 | 8 |
# | Convolution Filters | 3×3 | 11×11, 5×5 |
# | Accuracy | Higher | Moderate |
# | Training Speed | Slower | Faster |
# | Computational Cost | High | Lower |
# | Feature Learning | Better | Good |
# | Memory Usage | Higher | Lower |
#
# ### Summary
#
# - **VGG16** provides better feature extraction due to its deeper architecture.
# - **AlexNet** is computationally cheaper and faster to train.
# - VGG16 generally achieves **higher classification accuracy**.
#
# ---
