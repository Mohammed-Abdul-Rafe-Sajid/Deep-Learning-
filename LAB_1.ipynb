# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Abdul-Rafe-Sajid/Deep-Learning-/blob/main/LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## STEP 1: Install Required Libraries

# %%
# !pip install tensorflow keras torch torchvision #theano

# %% [markdown]
# ### Verify Installations

# %%
import tensorflow as tf
import keras
#import theano
import torch

print("TensorFlow Version:", tf.__version__)
print("Keras Version:", keras.__version__)
#print("Theano Version:", theano.__version__)
print("PyTorch Version:", torch.__version__)
# Out:
# TensorFlow Version: 2.19.0
# Keras Version: 3.10.0
# PyTorch Version: 2.9.0+cpu

# %% [markdown]
# STEP 2: Framework Overview (Conceptual)
# 1. TensorFlow
# - End-to-end ML framework by Google
# - Supports low-level and high-level APIs
# - Production-ready and scalable
#
# 2. Keras
# - High-level deep learning API
# - Easy to use and beginner-friendly
# - Runs on top of TensorFlow
#
# 3. Theano
# - One of the earliest deep learning libraries
# - Uses symbolic computation
# - Now mostly discontinued
#
# 4. PyTorch
# - Dynamic computation graph
# - Preferred for research and experimentation
# - Very Pythonic and flexible

# %% [markdown]
# ## STEP 3: Hands-On Exercises (MNIST Classification)
# ### 3.1 TensorFlow (MNIST Classification)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(x_train, y_train, epochs=3)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8793 - loss: 0.4313
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9658 - loss: 0.1186
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9774 - loss: 0.0787

# %% [markdown]
# ### 3.2 Keras (MNIST Classification)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.datasets import mnist

# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Build model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8768 - loss: 0.4395
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9661 - loss: 0.1155
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9760 - loss: 0.0796

# %% [markdown]
# ### 3.3 Theano (Simple Operation Example): Deprecated

# %%
# import theano
# import theano.tensor as T

# # Define symbolic variables
# x = T.dscalar('x')
# y = T.dscalar('y')

# # Define computation
# z = x + y

# # Compile function
# f = theano.function([x, y], z)

# # Test
# print(f(2, 3))  # Output: 5.0

# %% [markdown]
# ### 3.4 PyTorch (MNIST Classification)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transform
transform = transforms.ToTensor()

# Load dataset
train_data = datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

train_loader = DataLoader(
    train_data,
    batch_size=64,
    shuffle=True
)

# Define model
class NeuralNet(nn.Module):
    def __init__(self):
        super(NeuralNet, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = NeuralNet()

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
for epoch in range(3):
    for images, labels in train_loader:
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1} completed")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 12.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 343kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.16MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.35MB/s]
# Epoch 1 completed
# Epoch 2 completed
# Epoch 3 completed

# %% [markdown]
# | Framework  | Strengths                  | Weaknesses              |
# | ---------- | -------------------------- | ----------------------- |
# | TensorFlow | Production-ready, scalable | Verbose                 |
# | Keras      | Simple, beginner-friendly  | Less control            |
# | Theano     | Symbolic math              | Deprecated              |
# | PyTorch    | Flexible, dynamic          | Less production tooling |

# %% [markdown]
# ### BASIC CODES

# %%
import tensorflow as tf

x = tf.constant(5)
y = tf.constant(3)

result = tf.add(x, y)
print(result.numpy())
# Out:
# 8

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(32, input_shape=(10,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print("Keras model compiled successfully")
# Out:
# Keras model compiled successfully
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import torch

x = torch.tensor(5.0)
y = torch.tensor(3.0)

result = x + y
print(result)
# Out:
# tensor(8.)

# %% [markdown]
# | Feature     | TensorFlow            | Keras          | Theano      | PyTorch                |
# | ----------- | --------------------- | -------------- | ----------- | ---------------------- |
# | Ease of Use | Moderate              | High           | Low         | Moderate               |
# | Computation | Static Graphs         | High-level API | Symbolic    | Dynamic Graphs         |
# | GPU Support | Yes                   | Yes            | Yes         | Yes                    |
# | Popularity  | Very High             | High           | Moderate    | High                   |
# | Ideal For   | Production & Research | Beginners      | Researchers | Research & Development |
