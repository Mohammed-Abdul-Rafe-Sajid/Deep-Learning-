# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Abdul-Rafe-Sajid/Deep-Learning-/blob/main/Lab_6_AlexNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🧪 Experiment Description
#
# The objective of this experiment is to implement the **AlexNet Convolutional Neural Network (CNN)** architecture using Keras for image classification on the **CIFAR-10 dataset**.
#
# ---
#
# ## 📊 Dataset Description
#
# The **CIFAR-10 dataset** consists of:
#
# - **60,000 color images**
# - Image size: **32 × 32 pixels**
# - **10 different object classes**:
#   - Airplane
#   - Automobile
#   - Bird
#   - Cat
#   - Deer
#   - Dog
#   - Frog
#   - Horse
#   - Ship
#   - Truck
#
# ### 📂 Data Split
# - **50,000 images** → Training set
# - **10,000 images** → Testing set
# - Each class contains an equal number of images
#
# ---
#
# ## 🧠 Problem Statement
#
# Image classification is a fundamental problem in computer vision where a model must correctly identify the category of an image.
#
# Traditional machine learning methods struggle with image data because:
# - Images are **high-dimensional**
# - They contain **complex spatial patterns**
#
# ---
#
# ## 🤖 Solution: Convolutional Neural Networks (CNNs)
#
# **CNNs** solve this problem by automatically learning hierarchical features such as:
# - Edges
# - Textures
# - Shapes
# - Object parts
#
# ---
#
# ## 🏗️ AlexNet Architecture
#
# **AlexNet** is a deep CNN architecture known for its high performance in image recognition tasks.
#
# ### 🔹 Key Components:
# - **Convolutional Layers** → Extract visual features
# - **Max-Pooling Layers** → Reduce spatial dimensions
# - **Fully Connected Layers** → Learn complex relationships
# - **Softmax Layer** → Output class probabilities
#
# ---
#
# ## ⚙️ Data Preprocessing
#
# Before training, the dataset is processed as follows:
#
# - **Normalization**
#   - Pixel values scaled from **0–255 → 0–1**
#
# - **One-Hot Encoding**
#   - Converts class labels into vector format for multi-class classification
#
# ---
#
# ## 🚀 Model Training
#
# - **Optimizer:** Adam
# - **Loss Function:** Categorical Cross-Entropy
# - **Technique Used:** Early Stopping
#   - Prevents overfitting
#   - Stops training when validation loss stops improving
#
# ---
#
# ## 📈 Model Evaluation
#
# The trained model is evaluated on the test dataset using:
#
# - **Classification Accuracy**
#
# This demonstrates how deep learning models like **AlexNet** can effectively:
# - Learn complex image features
# - Perform accurate object recognition
#
# ---

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

model = models.Sequential()


model.add(layers.Conv2D(96, (11, 11), strides=(2,2), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(256,(5,5),activation='relu',padding='same'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(384,(3,3),activation='relu',padding='same'))
model.add(layers.Conv2D(384,(3,3),activation='relu',padding='same'))
model.add(layers.Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())

model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dropout(0.5))

model.add(layers.Dense(10,activation='softmax'))

model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss',patience=3)

history = model.fit(x_train,y_train,epochs=15,batch_size=64,validation_data=(x_test,y_test),callbacks=[early_stopping])

test_loss,test_acc = model.evaluate(x_test,y_test,verbose=2)

print("\nTest Accuracy:",test_acc)
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 24ms/step - accuracy: 0.2202 - loss: 2.0380 - val_accuracy: 0.3572 - val_loss: 1.6966
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3872 - loss: 1.6565 - val_accuracy: 0.4449 - val_loss: 1.5067
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.4580 - loss: 1.4926 - val_accuracy: 0.4848 - val_loss: 1.4140
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5003 - loss: 1.3897 - val_accuracy: 0.5164 - val_loss: 1.3359
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5338 - loss: 1.3078 - val_accuracy: 0.5063 - val_loss: 1.3745
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5618 - loss: 1.2408 - val_accuracy: 0.5383 - val_loss: 1.2959
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5878 - loss: 1.1701 - val_accuracy: 0.5366 - val_loss: 1.3160
# Epoch 8/15
# ...
